# %%
# Example 7
import matplotlib.pyplot as plt
# Defining coordinates to be plotted on X and Y axes
# respectively

x = [ 1.3, 2.9, 3.1, 4.7, 5.6, 6.5, 7.4, 8.8, 9.2, 10]
y = [95, 42, 69, 11, 49, 32, 74, 62, 25,32]

# plot lists 'x' and 'y'

plt.plot(x,y)

# Plot axes lables and show the plot

plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')

print(plt.show())
# Out:
# None

# %%
# Example 8
# plot line with green color

import matplotlib.pyplot as plt

plt.plot(y,'g')
# Plot axes labes and show the plot
plt.xlabel('Index Values')
plt.ylabel('Elements in List Y')
print(plt.show())
# Out:
# None

# %%
import matplotlib.pyplot as plt

# Example 10

# plot continuous green line with asterisk markers
plt.plot(y,'g*-')
# plot axes labels and show the plot
plt.xlabel('Index Values')
plt.ylabel('Elements in List Y')
print(plt.show())
# Out:
# None

# %%
# Example 11
# plot list 'y'

plt.plot(y,'g')
# Plot red circle markers

plt.plot(y,'ro')

# Plot axes labels and show the plot

plt.xlabel('Index Values')
plt.ylabel('Elements in list Y')
print(plt.show())
# Out:
# None

# %%
# example 12
# Define two lists

y = [95,42,69,11,49,32,74,2,25,32]
y2 = [35,52,96,77,36,66,50,12,35,63]

# Plot lists and show them

plt.plot(y,'go-')
plt.plot(y2,'b*--')
# plot axes labels and show the plot
plt.xlabel('Index Values')
plt.ylabel('Elements in Lists')
plt.show()

# %%
# Example 12 techniquie 2

# plot lists and show them
plt.plot(y,'go-',y2,'b*--')
# Plot axes labels and show the plot

plt.xlabel('Index Values')
plt.ylabel('Elements in Lists')
plt.show()

# %%
# Example 13

# Import numpy library
import numpy as np

# Drawing 30 samples from a standard normal distribution
# into an array 'arr'

arr = np.random.normal(size=30)
# Plotting 'arr' with dashed line-style and *markers
plt.plot(arr,color='teal',marker='*',linestyle='dashed')

# %%
# Example 14
# Creating a two-dimensional array 'arr_2d' with 40 samples
# and shape of (20,2)

arr_2d = np.random.normal(size=40).reshape(20,2)
# Plotting the array
plt.plot(arr_2d)
# Out:
# [<matplotlib.lines.Line2D at 0x1bdcd863fc8>,
#  <matplotlib.lines.Line2D at 0x1bdcd74b208>]

# %%
# Example 15
# Importing necessary libraries

import numpy as np
import pandas as pd
# Creating panda Series with 50 samples drawn from normal
# distribution

ts = pd.Series(np.random.normal(size=50),
              index=pd.date_range(start='1/1/2019',
                                 periods=50))

# Plotting pandas Series
ts.plot()

# %%
# Example 16
# Plotting pandas Series in green color
ts.plot(color='green')

# %%
# Script to fetch AAPL data from a web resource
import pandas as pd

# fetch data
data = pd.read_csv('https://bit.ly/2WcsJE7', index_col=0,
                   parse_dates=True)
print(data)
# Out:
#               Open    High       Low    Close      Volume  ExDividend  \
# Date
# 2018-03-27  173.68  175.15  166.9200  168.340  38962839.0         0.0
# 2018-03-26  168.07  173.10  166.4400  172.770  36272617.0         0.0
# 2018-03-23  168.39  169.92  164.9400  164.940  40248954.0         0.0
# 2018-03-22  170.00  172.68  168.6000  168.845  41051076.0         0.0
# 2018-03-21  175.04  175.09  171.2600  171.270  35247358.0         0.0
# ...            ...     ...       ...      ...         ...         ...
# 2013-12-26  568.10  569.50  563.3760  563.900   7286000.0         0.0
# 2013-12-24  569.89  571.88  566.0300  567.670   5984100.0         0.0
# 2013-12-23  568.00  570.72  562.7600  570.090  17903800.0         0.0
# 2013-12-20  545.43  551.61  544.8175  549.020  15586200.0         0.0
# 2013-12-19  549.50  550.00  543.7301  544.460  11439600.0         0.0
#
#             SplitRatio     AdjOpen     AdjHigh      AdjLow    AdjClose  \
# Date
# 2018-03-27         1.0  173.680000  175.150000  166.920000  168.340000
# 2018-03-26         1.0  168.070000  173.100000  166.440000  172.770000
# 2018-03-23         1.0  168.390000  169.920000  164.940000  164.940000
# 2018-03-22         1.0  170.000000  172.680000  168.600000  168.845000
# 2018-03-21         1.0  175.040000  175.090000  171.260000  171.270000
# ...                ...         ...         ...         ...         ...
# 2013-12-26         1.0   75.513273   75.699365   74.885347   74.954999
# 2013-12-24         1.0   75.751204   76.015720   75.238124   75.456116
# 2013-12-23         1.0   75.499981   75.861530   74.803467   75.777789
# 2013-12-20         1.0   72.499920   73.321381   72.418505   72.977112
# 2013-12-19         1.0   73.040915   73.107376   72.273965   72.370985
#
#               AdjVolume  Name
# Date
# 2018-03-27   38962839.0  AAPL
# 2018-03-26   36272617.0  AAPL
# 2018-03-23   40248954.0  AAPL
# 2018-03-22   41051076.0  AAPL
# 2018-03-21   35247358.0  AAPL
# ...                 ...   ...
# 2013-12-26   51002000.0  AAPL
# 2013-12-24   41888700.0  AAPL
# 2013-12-23  125326600.0  AAPL
# 2013-12-20  109103400.0  AAPL
# 2013-12-19   80077200.0  AAPL
#
# [1072 rows x 13 columns]

# %%
# Exanple 17
# plot volume column
data.Volume.iloc[:100].plot()

# %%
# Example 18
data[['AdjOpen','AdjClose']][:50].plot()
